# %%
import datalook

# %%
help(datalook.analyse)
# Out:
# Help on function analyse in module datalook:
#
# analyse(filename, outfile=None)
#     Brings up max, min and average plots for the data in sublots for filename argument.

# %%
datalook.analyse ('data/data/weather-02.csv')
